# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import make_scorer

raw_data = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
raw_data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
raw_data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
raw_data = raw_data.dropna(axis=0).reset_index(drop=True)
raw_data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     31112    Male  80.0             0              1          Yes
# 2     60182  Female  49.0             0              0          Yes
# 3      1665  Female  79.0             1              0          Yes
# 4     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 4904  14180  Female  13.0             0              0           No
# 4905  44873  Female  81.0             0              0          Yes
# 4906  19723  Female  35.0             0              0          Yes
# 4907  37544    Male  51.0             0              0          Yes
# 4908  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1           Private          Rural             105.92  32.5     never smoked
# 2           Private          Urban             171.23  34.4           smokes
# 3     Self-employed          Rural             174.12  24.0     never smoked
# 4           Private          Urban             186.21  29.0  formerly smoked
# ...             ...            ...                ...   ...              ...
# 4904       children          Rural             103.08  18.6          Unknown
# 4905  Self-employed          Urban             125.20  40.0     never smoked
# 4906  Self-employed          Rural              82.99  30.6     never smoked
# 4907        Private          Rural             166.29  25.6  formerly smoked
# 4908       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 4904       0
# 4905       0
# 4906       0
# 4907       0
# 4908       0
#
# [4909 rows x 12 columns]

# %%
raw_data.describe(include='all')
# Out:
#                   id  gender          age  hypertension  heart_disease  \
# count    4909.000000    4909  4909.000000   4909.000000    4909.000000
# unique           NaN       3          NaN           NaN            NaN
# top              NaN  Female          NaN           NaN            NaN
# freq             NaN    2897          NaN           NaN            NaN
# mean    37064.313506     NaN    42.865374      0.091872       0.049501
# std     20995.098457     NaN    22.555115      0.288875       0.216934
# min        77.000000     NaN     0.080000      0.000000       0.000000
# 25%     18605.000000     NaN    25.000000      0.000000       0.000000
# 50%     37608.000000     NaN    44.000000      0.000000       0.000000
# 75%     55220.000000     NaN    60.000000      0.000000       0.000000
# max     72940.000000     NaN    82.000000      1.000000       1.000000
#
#        ever_married work_type Residence_type  avg_glucose_level          bmi  \
# count          4909      4909           4909        4909.000000  4909.000000
# unique            2         5              2                NaN          NaN
# top             Yes   Private          Urban                NaN          NaN
# freq           3204      2811           2490                NaN          NaN
# mean            NaN       NaN            NaN         105.305150    28.893237
# std             NaN       NaN            NaN          44.424341     7.854067
# min             NaN       NaN            NaN          55.120000    10.300000
# 25%             NaN       NaN            NaN          77.070000    23.500000
# 50%             NaN       NaN            NaN          91.680000    28.100000
# 75%             NaN       NaN            NaN         113.570000    33.100000
# max             NaN       NaN            NaN         271.740000    97.600000
#
#        smoking_status       stroke
# count            4909  4909.000000
# unique              4          NaN
# top      never smoked          NaN
# freq             1852          NaN
# mean              NaN     0.042575
# std               NaN     0.201917
# min               NaN     0.000000
# 25%               NaN     0.000000
# 50%               NaN     0.000000
# 75%               NaN     0.000000
# max               NaN     1.000000

# %%
raw_data['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
raw_data = raw_data.drop(raw_data[raw_data['gender'] == 'Other'].index, axis=0).reset_index(drop=True)
raw_data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     31112    Male  80.0             0              1          Yes
# 2     60182  Female  49.0             0              0          Yes
# 3      1665  Female  79.0             1              0          Yes
# 4     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 4903  14180  Female  13.0             0              0           No
# 4904  44873  Female  81.0             0              0          Yes
# 4905  19723  Female  35.0             0              0          Yes
# 4906  37544    Male  51.0             0              0          Yes
# 4907  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1           Private          Rural             105.92  32.5     never smoked
# 2           Private          Urban             171.23  34.4           smokes
# 3     Self-employed          Rural             174.12  24.0     never smoked
# 4           Private          Urban             186.21  29.0  formerly smoked
# ...             ...            ...                ...   ...              ...
# 4903       children          Rural             103.08  18.6          Unknown
# 4904  Self-employed          Urban             125.20  40.0     never smoked
# 4905  Self-employed          Rural              82.99  30.6     never smoked
# 4906        Private          Rural             166.29  25.6  formerly smoked
# 4907       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 4903       0
# 4904       0
# 4905       0
# 4906       0
# 4907       0
#
# [4908 rows x 12 columns]

# %%
raw_data.drop(['id'],inplace=True,axis=1)

# %%
raw_data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4903  Female  13.0             0              0           No       children
# 4904  Female  81.0             0              0          Yes  Self-employed
# 4905  Female  35.0             0              0          Yes  Self-employed
# 4906    Male  51.0             0              0          Yes        Private
# 4907  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4903          Rural             103.08  18.6          Unknown       0
# 4904          Urban             125.20  40.0     never smoked       0
# 4905          Rural              82.99  30.6     never smoked       0
# 4906          Rural             166.29  25.6  formerly smoked       0
# 4907          Urban              85.28  26.2          Unknown       0
#
# [4908 rows x 11 columns]

# %%
print(raw_data['gender'].unique())
print(raw_data['ever_married'].unique())
print(raw_data['Residence_type'].unique())
print(raw_data['work_type'].unique())
print(raw_data['smoking_status'].unique())
# Out:
# ['Male' 'Female']
# ['Yes' 'No']
# ['Urban' 'Rural']
# ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
# ['formerly smoked' 'never smoked' 'smokes' 'Unknown']

# %%
raw_data['gender'] = raw_data['gender'].replace({'Male':0,'Female':1})
raw_data['ever_married'] = raw_data['ever_married'].replace({'No':0,'Yes':1})
raw_data['Residence_type'] = raw_data['Residence_type'].replace({'Rural':0,'Urban':1})
raw_data['work_type'] = raw_data['work_type'].replace({'Private':0,'Self-employed':1,'Govt_job':2,'children':3,'Never_worked':4})
raw_data['smoking_status'] = raw_data['smoking_status'].replace({'never smoked':0,'Unknown':1,'formerly smoked': 2,'smokes':3})

# %%
raw_data
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          0  67.0             0              1             1          0
# 1          0  80.0             0              1             1          0
# 2          1  49.0             0              0             1          0
# 3          1  79.0             1              0             1          1
# 4          0  81.0             0              0             1          0
# ...      ...   ...           ...            ...           ...        ...
# 4903       1  13.0             0              0             0          3
# 4904       1  81.0             0              0             1          1
# 4905       1  35.0             0              0             1          1
# 4906       0  51.0             0              0             1          0
# 4907       1  44.0             0              0             1          2
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0                  1             228.69  36.6               2       1
# 1                  0             105.92  32.5               0       1
# 2                  1             171.23  34.4               3       1
# 3                  0             174.12  24.0               0       1
# 4                  1             186.21  29.0               2       1
# ...              ...                ...   ...             ...     ...
# 4903               0             103.08  18.6               1       0
# 4904               1             125.20  40.0               0       0
# 4905               0              82.99  30.6               0       0
# 4906               0             166.29  25.6               2       0
# 4907               1              85.28  26.2               1       0
#
# [4908 rows x 11 columns]

# %%
corr=raw_data.corr()
corr
# Out:
#                      gender       age  hypertension  heart_disease  \
# gender             1.000000  0.030280     -0.021811      -0.082950
# age                0.030280  1.000000      0.274395       0.257104
# hypertension      -0.021811  0.274395      1.000000       0.115978
# heart_disease     -0.082950  0.257104      0.115978       1.000000
# ever_married       0.036380  0.680742      0.162350       0.111203
# work_type         -0.070889 -0.415506     -0.073458      -0.054965
# Residence_type     0.004351  0.010795     -0.001140      -0.002409
# avg_glucose_level -0.053161  0.236000      0.180614       0.154577
# bmi                0.026164  0.333314      0.167770       0.041322
# smoking_status    -0.064168  0.080461      0.010515       0.067151
# stroke            -0.006904  0.232313      0.142503       0.137929
#
#                    ever_married  work_type  Residence_type  avg_glucose_level  \
# gender                 0.036380  -0.070889        0.004351          -0.053161
# age                    0.680742  -0.415506        0.010795           0.236000
# hypertension           0.162350  -0.073458       -0.001140           0.180614
# heart_disease          0.111203  -0.054965       -0.002409           0.154577
# ever_married           1.000000  -0.378109        0.004707           0.151657
# work_type             -0.378109   1.000000        0.012931          -0.063029
# Residence_type         0.004707   0.012931        1.000000          -0.007441
# avg_glucose_level      0.151657  -0.063029       -0.007441           1.000000
# bmi                    0.341553  -0.347412       -0.000293           0.175672
# smoking_status         0.085798  -0.050086        0.032694           0.018793
# stroke                 0.105051  -0.057569        0.005988           0.138984
#
#                         bmi  smoking_status    stroke
# gender             0.026164       -0.064168 -0.006904
# age                0.333314        0.080461  0.232313
# hypertension       0.167770        0.010515  0.142503
# heart_disease      0.041322        0.067151  0.137929
# ever_married       0.341553        0.085798  0.105051
# work_type         -0.347412       -0.050086 -0.057569
# Residence_type    -0.000293        0.032694  0.005988
# avg_glucose_level  0.175672        0.018793  0.138984
# bmi                1.000000        0.047944  0.042341
# smoking_status     0.047944        1.000000  0.029772
# stroke             0.042341        0.029772  1.000000

# %%
raw_data.drop(['gender','Residence_type','bmi'],inplace=True,axis=1)
raw_data
# Out:
#        age  hypertension  heart_disease  ever_married  work_type  \
# 0     67.0             0              1             1          0
# 1     80.0             0              1             1          0
# 2     49.0             0              0             1          0
# 3     79.0             1              0             1          1
# 4     81.0             0              0             1          0
# ...    ...           ...            ...           ...        ...
# 4903  13.0             0              0             0          3
# 4904  81.0             0              0             1          1
# 4905  35.0             0              0             1          1
# 4906  51.0             0              0             1          0
# 4907  44.0             0              0             1          2
#
#       avg_glucose_level  smoking_status  stroke
# 0                228.69               2       1
# 1                105.92               0       1
# 2                171.23               3       1
# 3                174.12               0       1
# 4                186.21               2       1
# ...                 ...             ...     ...
# 4903             103.08               1       0
# 4904             125.20               0       0
# 4905              82.99               0       0
# 4906             166.29               2       0
# 4907              85.28               1       0
#
# [4908 rows x 8 columns]

# %%
from pycaret.classification import *
clf1 = setup(data = raw_data, target = 'stroke')
# Out:
# <style  type="text/css" >
# #T_e1a92a03_7e4a_11ec_8d28_70665578709crow44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_e1a92a03_7e4a_11ec_8d28_70665578709c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow0_col1" class="data row0 col1" >5857</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow1_col1" class="data row1 col1" >stroke</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow3_col1" class="data row3 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow4_col1" class="data row4 col1" >(4908, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow6_col1" class="data row6 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow7_col1" class="data row7 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow11_col1" class="data row11 col1" >(3435, 14)</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow12_col1" class="data row12 col1" >(1473, 14)</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_e1a92a03_7e4a_11ec_8d28_70665578709clevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_e1a92a03_7e4a_11ec_8d28_70665578709crow18_c

# %%
compare_models(sort = 'F1')
# Out:
# <style  type="text/css" >
#     #T_ffd4c109_7e4a_11ec_98ae_70665578709c th {
#           text-align: left;
#     }#T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col6,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow1_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow1_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow1_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow1_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow1_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow1_col5,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow1_col6,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow1_col7,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow2_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow2_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow2_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow2_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow2_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow2_col5,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow2_col7,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow3_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow3_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow3_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow3_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow3_col5,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow3_col6,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow3_col7,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow4_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow4_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow4_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow4_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow4_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow4_col5,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow4_col6,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow4_col7,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow5_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow5_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow5_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow5_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow5_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow5_col5,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow5_col6,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow5_col7,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow6_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow6_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow6_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow6_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow6_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow6_col5,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow6_col6,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow6_col7,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow7_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow7_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow7_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow7_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow7_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow7_col5,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow7_col6,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow7_col7,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow8_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow8_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow8_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow8_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow8_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow8_col5,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow8_col6,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow8_col7,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow9_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow9_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow9_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow9_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow9_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow9_col5,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow9_col6,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow9_col7,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow10_col0,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow10_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow10_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow10_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow10_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow10_col5,#T_ffd4c109_7e4a_11e ...
#             text-align:  left;
#             text-align:  left;
#         }#T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col3,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col5,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col7,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow2_col6,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow3_col4,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow11_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow11_col2,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow12_col1,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow13_col1{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow1_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow2_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow3_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow4_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow5_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow6_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow7_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow8_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow9_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow10_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow11_col8,#T_ffd4c109_7e4a_11ec_98ae_70665578709crow12_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_ffd4c109_7e4a_11ec_98ae_70665578709crow13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_ffd4c109_7e4a_11ec_98ae_70665578709c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ffd4c109_7e4a_11ec_98ae_70665578709clevel0_row0" class="row_heading level0 row0" >nb</th>
#                         <td id="T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col0" class="data row0 col0" >Naive Bayes</td>
#                         <td id="T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col1" class="data row0 col1" >0.5554</td>
#                         <td id="T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col2" class="data row0 col2" >0.8039</td>
#                         <td id="T_ffd4c109_7e4a_11ec_98ae_70665578709crow0_col3" class="data row0
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
from sklearn.model_selection import train_test_split

data,labels = raw_data.iloc[:,:7],raw_data['stroke']

X_train, X_test, y_train, y_test = train_test_split(data, labels, 
                                                    test_size=0.3, 
                                                    random_state=0, 
                                                    shuffle=True, 
                                                    stratify=labels)

# %%
from imblearn.over_sampling import SMOTE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
classifier = LinearDiscriminantAnalysis()
model = classifier.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
df_result = pd.DataFrame(columns=['model', 'tp', 'tn', 'fp', 'fn', 'correct', 'incorrect',
                                  'accuracy', 'precision', 'recall', 'f1', 'roc_auc','avg_pre'])

tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)
row = {'model': 'LinearDiscriminantAnalysis without SMOTE',
        'tp': tp,
        'tn': tn,
        'fp': fp,
        'fn': fn,
        'correct': tp+tn,
        'incorrect': fp+fn,
        'accuracy': round(accuracy,3),
        'precision': round(precision,3),
        'recall': round(recall,3),
        'f1': round(f1,3),
        'roc_auc': round(roc_auc,3),
        'avg_pre': round(avg_precision,3),
    }

df_result = df_result.append(row, ignore_index=True)
df_result.head()
# Out:
#                                       model tp    tn  fp  fn correct  \
# 0  LinearDiscriminantAnalysis without SMOTE  6  1387  23  57    1393
#
#   incorrect  accuracy  precision  recall    f1  roc_auc  avg_pre
# 0        80     0.946      0.207   0.095  0.13    0.539    0.058

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, 
                                                    test_size=0.3, 
                                                    random_state=0, 
                                                    shuffle=True, 
                                                    stratify=labels)

# %%
oversampled = SMOTE(random_state=0)
X_train_smote, y_train_smote = oversampled.fit_sample(X_train, y_train)

# %%
y_train_smote.value_counts()
# Out:
# 1    3289
# 0    3289
# Name: stroke, dtype: int64

# %%
classifier_smote = LinearDiscriminantAnalysis()
model = classifier_smote.fit(X_train_smote, y_train_smote)
y_pred_smote = model.predict(X_test)

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_smote).ravel()
accuracy = accuracy_score(y_test, y_pred_smote)
precision = precision_score(y_test, y_pred_smote)
recall = recall_score(y_test, y_pred_smote)
f1 = f1_score(y_test, y_pred_smote)
roc_auc = roc_auc_score(y_test, y_pred_smote)
avg_precision = average_precision_score(y_test, y_pred_smote)

# %%
row = {'model': 'LinearDiscriminantAnalysis with SMOTE',
        'tp': tp,
        'tn': tn,
        'fp': fp,
        'fn': fn,
        'correct': tp+tn,
        'incorrect': fp+fn,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'roc_auc': roc_auc,
        'avg_pre': round(avg_precision,3),       
    }
df_result = df_result.append(row, ignore_index=True)
df_result.head()
# Out:
#                                       model  tp    tn   fp  fn correct  \
# 0  LinearDiscriminantAnalysis without SMOTE   6  1387   23  57    1393
# 1     LinearDiscriminantAnalysis with SMOTE  40  1050  360  23    1090
#
#   incorrect  accuracy  precision    recall        f1   roc_auc  avg_pre
# 0        80  0.946000      0.207  0.095000  0.130000  0.539000    0.058
# 1       383  0.739986      0.100  0.634921  0.172786  0.689801    0.079
